# %%
import matplotlib.pyplot as plt
import pickle

# Create a sample figure
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [4, 5, 6])

# Save the figure as a pickle file
with open("figure.pkl", "wb") as f:
    pickle.dump(fig, f)

# %%
import pickle

# Load the figure
with open("figure.pkl", "rb") as f:
    fig = pickle.load(f)

# Show the figure
fig.show()
# Out:
# C:\Users\herie\AppData\Local\Temp\ipykernel_25992\4024495723.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# create a mosaic of subplots 16:9

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.offsetbox import AnnotationBbox, OffsetImage

# create a mosaic of subplots 16:9
mosaic = """
AAAABBRRRRRMMMMM
AAAABBRRRRRMMMMM
AAAABBRRRRRMMMMM
CCCCCCEEEEEMMMMM
CCCCCCEEEEEMMMMM
CCCCCCEEEEEJJJJJ
CCCCCCDDDDDJJJJJ
CCCCCCDDDDDOOOOO
CCCCCCDDDDDOOOOO
"""

fig, axd = plt.subplot_mosaic(mosaic, figsize=(16, 9))

# %%
import pickle

# Load the figure
with open(r"C:\Heri\GitHub\.Semester\Data-Visualization\04-Crypto-Dashboard\pkl\02-pesos-buy.pkl", "rb") as f:
    figp1 = pickle.load(f)
# Out:
# C:\Users\herie\AppData\Local\Temp\ipykernel_21912\3564876017.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   figp1.show()

# %%
with open(r"C:\Heri\GitHub\.Semester\Data-Visualization\04-Crypto-Dashboard\pkl\02-pesos-cfd.pkl", "rb") as f:
    figp2 = pickle.load(f)

# %%
with open(r"C:\Heri\GitHub\.Semester\Data-Visualization\04-Crypto-Dashboard\pkl\03-clustermap.pkl", "rb") as f:
    figcm = pickle.load(f)

# %%
import matplotlib.gridspec
from matplotlib.figure import SubplotParams

# Map the missing attribute to the correct location
matplotlib.gridspec.SubplotParams = SubplotParams

# %%
import matplotlib.figure  # Ensure SubplotParams is available
with open(r"C:\Heri\GitHub\.Semester\Data-Visualization\04-Crypto-Dashboard\pkl\05-bp1m.pkl", "rb") as f:
    figbp = pickle.load(f)
# Out:
# C:\Users\herie\AppData\Local\Temp\ipykernel_21912\2677074105.py:3: UserWarning: This figure was saved with matplotlib version 3.10.0 and is unlikely to function correctly.
#   figbp = pickle.load(f)
# Error in callback <function _draw_all_if_interactive at 0x0000019640BB0040> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\herie\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File c:\Users\herie\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
# ...

# %%
with open(r"C:\Heri\GitHub\.Semester\Data-Visualization\04-Crypto-Dashboard\pkl\05-bp1m.pkl", "rb") as f:
    figbp = pickle.load(f)
# Out:
# C:\Users\herie\AppData\Local\Temp\ipykernel_21912\1578094483.py:2: UserWarning: This figure was saved with matplotlib version 3.10.0 and is unlikely to function correctly.
#   figbp = pickle.load(f)
# Error in callback <function _draw_all_if_interactive at 0x0000019640BB0040> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\herie\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File c:\Users\herie\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
# ...

# %%
# filepath: c:\Heri\GitHub\.Semester\Data-Visualization\04-Crypto-Dashboard\eua.ipynb
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from svglib.svglib import svg2rlg
# Ensure the required extras are installed
# %pip install reportlab[renderPM]

from reportlab.graphics import renderPM
from PIL import Image
import io

# Crear un mosaico de subplots 16:9
mosaic = """
AAAABBRRRRRMMMMM
AAAABBRRRRRMMMMM
AAAABBRRRRRMMMMM
CCCCCCEEEEEMMMMM
CCCCCCEEEEEMMMMM
CCCCCCEEEEEJJJJJ
CCCCCCDDDDDJJJJJ
CCCCCCDDDDDOOOOO
CCCCCCDDDDDOOOOO
"""

fig, axd = plt.subplot_mosaic(mosaic, figsize=(16, 9))

# Ruta del archivo SVG
svgA_path = r'C:\Heri\GitHub\.Semester\Data-Visualization\04-Crypto-Dashboard\svg\02-pesos-buy.svg'

# Cargar el archivo SVG y convertirlo a PNG
drawing = svg2rlg(svgA_path)
svgA_image = io.BytesIO()

# Agregar la imagen SVG al subplot 'A'
imagebox = OffsetImage(svgA_image, zoom=0.5)
ab = AnnotationBbox(imagebox, (0.5, 0.5), frameon=False)
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: reportlab[renderPM] in c:\users\herie\appdata\local\programs\python\python312\lib\site-packages (4.3.1)
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 35
#      32 svgA_image = io.BytesIO()
#      34 # Agregar la imagen SVG al subplot 'A'
# ---> 35 imagebox = OffsetImage(svgA_image, zoom=0.5)
#      36 ab = AnnotationBbox(imagebox, (0.5, 0.5), frameon=False)
#
# File c:\Users\herie\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\offsetbox.py:1173, in OffsetImage.__init__(self, arr, zoom, cmap, norm, interpolation, origin, filternorm, filterrad, resample, dpi_cor, **kwargs)
#    1170 self._children = [self.image]
# ...

# %%
# %pip install reportlab[renderPM]
# Out:
# ...
#    ---------------------------------------- 0.0/385.7 kB ? eta -:--:--
#    - -------------------------------------- 10.2/385.7 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/385.7 kB 217.9 kB/s eta 0:00:02
#    ---- ---------------------------------- 41.0/385.7 kB 326.8 kB/s eta 0:00:02
#    --------- ----------------------------- 92.2/385.7 kB 525.1 kB/s eta 0:00:01
#    ----------------------- ---------------- 225.3/385.7 kB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 307.2/385.7 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  378.9/385.7 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 385.7/385.7 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install RENDERPM
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement RENDERPM (from versions: none)
# ERROR: No matching distribution found for RENDERPM
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
drawing
